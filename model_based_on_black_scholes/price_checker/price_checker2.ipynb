# %%
import pandas as pd

# %%
data = {}
date_declaration = ["22.01.2020", "11.02.2020", "31.01.2020", "14.02.2020", 
                    "22.10.2019", "19.09.2017"]
companies = ["American Airlines-US", "Occidental Petroleum", "Entergy", "FedEx", 
             "American Electric Power", "Pacific Gas and Electric Company"]
tickers = ["AAL", "OXY", "ETR", "FDX", "AEP", "PCG"]
stock_price_day_before = [27.20, 40.50, 131.72, 161.48, 94.48, 69.65]
stock_price_day = [29.24, 42.18, 130.82, 162.22, 94.26, 69.76]
stock_price_day_after = [26.66, 38.52, 129.94, 161.28, 93.44, 69.42]
dividend = ["increased", "increased", "decreased", "not changed", "decreased", "not changed"]
put_options_day_before = ['decreased' for _ in range(len(tickers))]
put_options_day_before[5] = 'increased'
put_options_day_before[2] = 'increased'
put_options_day = ['decreased', 'decreased', 'increased', 'decreased', 'increased', 'increased']
put_options_day_after = ['increased' for _ in range(len(tickers))]
data['company'] = companies
data['ticker'] = tickers
data['dividend release day'] = date_declaration
data['stock price day before'] = stock_price_day_before
data['stock price on release day'] = stock_price_day
data['stock price day after'] = stock_price_day_after
data['dividend payment'] = dividend
data['put options day before'] = put_options_day_before
data['put options on release day'] = put_options_day
data['put options day after'] = put_options_day_after
data['options_dd'] = ["05.06.2020", "17.07.2020", "18.09.2020", "15.01.2021", "19.06.2020", "20.05.2018"]
df = pd.DataFrame(data)

# %%
df
# Out:
#                             company ticker dividend release day  \
# 0              American Airlines-US    AAL           22.01.2020
# 1              Occidental Petroleum    OXY           11.02.2020
# 2                           Entergy    ETR           31.01.2020
# 3                             FedEx    FDX           14.02.2020
# 4           American Electric Power    AEP           22.10.2019
# 5  Pacific Gas and Electric Company    PCG           19.09.2017
#
#    stock price day before  stock price on release day  stock price day after  \
# 0                   27.20                       29.24                  26.66
# 1                   40.50                       42.18                  38.52
# 2                  131.72                      130.82                 129.94
# 3                  161.48                      162.22                 161.28
# 4                   94.48                       94.26                  93.44
# ...
